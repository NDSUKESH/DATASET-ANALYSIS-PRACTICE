# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json

# %%
df=pd.read_csv('/content/Tokyo Medals 2021.csv')

# %%
df.head(5)
# Out:
#                       Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank By Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
df=df.head(15)

# %%
plt.subplots(figsize=(15,5))
ax=sns.barplot(data=df,x='Total',y='Country')
for i in ax.containers:
  ax.bar_label(i,)

# %%
ax=df.plot(x="Country", y=["Silver Medal","Gold Medal","Bronze Medal"], kind="bar",figsize=(15,8))
for i in ax.containers:
  ax.bar_label(i,)
